# %% [markdown]
# <h1 style="text-align: center;">TP1 - Desenvolvimento de Serviços Web e Testes com Java</h1>

# %% [markdown]
# | ![Logo Infnet](https://mir-s3-cdn-cf.behance.net/projects/404/9115f025917929.5547cdc9cda40.jpg) |
# |:-------------------------------------------------------------------------:|

# %% [markdown]
# <h5 style="text-align: center;">Professor: Bernardo Prattes || Estudante: Paulo Henrique de Paula Dias</h5>

# %% [markdown]
# <h5 style="text-align: center;">Data limite: 05/05/2025</h5>

# %% [markdown]
# ##### Links úteis:
#
# Repositório Git Hub - [Link](https://github.com/PAULOHENRIQUEDEPAULADIAS/Paulo_Dias_TJ_TP1v2)

# %% [markdown]
# ### Ponto de Partida

# %% [markdown]
# Você deverá testar a classe ScientificCalculator, que representa uma calculadora científica com operações básicas e avançadas. Os métodos já estão implementados. Seu papel será criar testes unitários utilizando JUnit, segundo os princípios aprendidos.

# %% [markdown]
# ### Classe a ser testada - ScientificCalculator.java

# %%
public class ScientificCalculator {

    public double add(double a, double b) {
        return a + b;
    }

    public double subtract(double a, double b) {
        return a - b;
    }

    public double multiply(double a, double b) {
        return a * b;
    }

    public double divide(double a, double b) {
        if (b == 0) throw new IllegalArgumentException("Division by zero");
        return a / b;
    }

    public double power(double base, double exponent) {
        return Math.pow(base, exponent);
    }

    public double squareRoot(double a) {
        if (a < 0) throw new IllegalArgumentException("Negative number");
        return Math.sqrt(a);
    }

    public double log(double a) {
        if (a <= 0) throw new IllegalArgumentException("Log of non-positive number");
        return Math.log(a);
    }

    public double sin(double degrees) {
        return Math.sin(Math.toRadians(degrees));
    }

    public double cos(double degrees) {
        return Math.cos(Math.toRadians(degrees));
    }
}

# %% [markdown]
# ### Exercício 1 -  Configurando o ambiente de testes

# %% [markdown]
# * Crie um projeto Java em sua IDE IntelliJ IDEA e adicione corretamente a dependência do JUnit 5. Faça a configuração necessária para que seja possível executar testes unitários com sucesso. Tire um print do ambiente configurado.

# %% [markdown]
# ### Resolução do exercício 1

# %% [markdown]
# ![image.png](attachment:c9536373-fb1d-43ef-9ee3-a7157c6c6ef2.png)

# %% [markdown]
# ### Exercício 2 - Escrevendo o primeiro teste

# %% [markdown]
# Implemente um teste chamado testAddition para verificar se o método add retorna corretamente o valor da soma de dois números. No final da implementação, execute o teste e responda:
#
# O que aparece no painel de execução?
#
# * Mostre o código do teste.
# * Tire um print do resultado.
# * Escreva o que significam os ícones e mensagens exibidas.

# %% [markdown]
# ### Resolução do exercício 2

# %% [markdown]
# #### Código

# %% [markdown]
# public class ScientifcCalculatorTest {
#
#     //Para fins de legibilidade, nomeei a classe igualmente a classe que está sendo testada
#     @Test
#     public void testAddition(){
#         ScientificCalculator calculator = new ScientificCalculator();
#
#         double addition = calculator.add(1, 2);
#
#         assertEquals(3, addition);
#
#     }
# }

# %% [markdown]
# #### Print do resultado

# %% [markdown]
# ![image.png](attachment:3d7d33bc-1631-4a10-9719-b556fd3c194c.png)

# %% [markdown]
# No campo inferior esquerdo temos o ícone verde juntamente com o nome do teste realizado, indicando que o teste funcionou como esperado em 17ms.
# No campo inferior central, temos a exibição central do processo, onde no caso de erros, é exibido neste campo a diferença apresentada, e no campo inferior esquerdo os ícones verdes se tornam amarelos. e.g. abaixo:

# %% [markdown]
# ![image.png](attachment:8f8f9dcf-8e0e-4bfc-bacb-c493634b98a9.png)

# %% [markdown]
# ### Exercício 3 - Aplicando as 4 fases de um teste

# %% [markdown]
# * Crie um teste para o método subtract, utilizando as quatro fases de um teste unitário: setup, execution, assertion, e teardown (se aplicável). Comente no código onde cada fase está localizada.

# %% [markdown]
# ### Resolução do exercício 3

# %% [markdown]
#  @Test
#     void testSubtract() {
#
#         //Setup
#         ScientificCalculator calculator = new ScientificCalculator();
#
#         //Execution
#         double sub = calculator.subtract(1, 3);
#
#         //Assertion
#         assertEquals(-2, sub);
#
#         //Teardown
#         System.out.println("Final do teste");
#     }

# %% [markdown]
# A área de Setup indica onde o código irá iniciar, nesse caso o início é a instância de ScientificCalculator como calculator.\n
# Após temos o Execution, que indica a evocação do método e armazenamento do resultado na variável sub. \n
# Em seguida, o Assertion verifica se o resultado está coerente com o que esperamos que seja retornado dentro da variável sub. \n
# E por fim temos o campo Teardown, que basicamente encerra qualquer abertura que tenha sido feita no código, neste caso simbolicamente fiz o encerramento com uma mensagem indicando o fim do teste. Mas pode ser usado para fechamento de leitores de documentos por exemplo.

# %% [markdown]
# ### Exercício 4 - Test Fixture com BeforeEach

# %% [markdown]
# * Implemente um @BeforeEach para instanciar o objeto ScientificCalculator antes de cada teste. Mostre que o mesmo objeto pode ser reaproveitado entre diferentes métodos de teste.

# %% [markdown]
# ### Resolução do exercício 4

# %% [markdown]
# Adaptação dos dois métodos anteriormente criados (testSubtract() e testAddition()) com a requisição do @BeforeEach e adicionados o @AfterEach

# %% [markdown]
# public class ScientifcCalculatorTest {<br>
#     private ScientificCalculator calc;

# %% [markdown]
#     // Aqui ocorre o set up, indica que o teste se inicia com essa instância
#     // de calc e pode ser usado em todos os testes seguintes.
#     // O setUp() é iniciado toda vez que uma unidade de teste é acionada graças ao @BeforeEach.
#     @BeforeEach
#     void setUp() {
#         calc = new ScientificCalculator();
#         System.out.println("Iniciando teste.");
#     }
#
#     // Tear down é algum possível fechamento que precisa ser realizado, indica por exemplo,
#     // o fechamento do leitor de documentos por exemplo. Aqui para fins de visualização, o coloquei com uma
#     // mensagem de encerramento.
#     @AfterEach
#     void tearDown() {
#         System.out.println("Finalizando teste");
#     }
#
#     // testAddition() aciona a fase de execution e assertion. Sendo execution a linha recebendo calc.subtract
#     // e assertion a linha assertEquals();
#     @Test
#     void testAddition(){
#         double addition = calc.add(1,2);
#
#         assertEquals(3, addition);
#     }
#
#     // testSubract() aciona a fase de execution e assertion. Sendo execution a linha recebendo calc.subtract
#     // e assertion a linha assertEquals();
#     @Test
#     void testSubtract() {
#         double sub = calc.subtract(1, 3);
#
#         assertEquals(-2, sub);
#     }

# %% [markdown]
# ### Exercício 5 - Testando um cenário de sucesso (Happy Path)

# %% [markdown]
# * Implemente um teste chamado testSquareRootPositive para verificar se o cálculo da raiz quadrada de um número positivo está correto.

# %% [markdown]
# ### Resolução do exercício 5

# %% [markdown]
# Para o exercício acima, utilizei dos mesmos utilitários dos exercícios anteriores (@BeforeEach, AfterEach).

# %% [markdown]
# @Test
#     void testSquaredRoot(){
#
#         double sqr = calc.squareRoot(25);
#
#
#         assertEquals(5, sqr);
#
#     }

# %% [markdown]
# ![image.png](attachment:16022216-f636-49f5-8bb2-1fcc78d905d7.png)

# %% [markdown]
# ### Exercício 6 - Testando um cenário patológico (Corner Case)

# %% [markdown]
# * Implemente um teste chamado testSquareRootNegative que verifica se o método squareRoot lança uma exceção apropriada ao receber um número negativo. Use assertThrows.

# %% [markdown]
# ### Resolução do exercício 6

# %% [markdown]
# @Test
#     void testSquareRootNegative(){
#
#         Exception res = assertThrows(IllegalArgumentException.class, () -> calc.squareRoot(-25) ) ;
#
#         assertEquals("Negative number", res.getMessage());
#     }

# %% [markdown]
# ![image.png](attachment:d931b51d-f3bb-4ded-82c4-b33b3eebb4ac.png)

# %% [markdown]
# ### Exercício 7 - Cenário de exceção (divisão por zero)

# %% [markdown]
# * Implemente um teste chamado testDivideByZero, verificando se o método divide lança IllegalArgumentException ao tentar dividir por zero.

# %% [markdown]
# ### Resolução do exercício 7

# %% [markdown]
# @Test
#     void testDivideByZero(){
#
#         Exception res = assertThrows(IllegalArgumentException.class, () -> calc.divide(10, 0));
#
#         assertEquals("Division by zero", res.getMessage());
#     }

# %% [markdown]
# ![image.png](attachment:b39ebe2f-c596-40e0-add6-3835bab2f159.png)

# %% [markdown]
# ### Exercício 8 - Combinando múltiplas entradas (log e seno)

# %% [markdown]
# * Implemente testes para os métodos log e sin, garantindo a precisão dos resultados esperados para valores positivos comuns. ***ADICIONADO TESTE PARA COS

# %% [markdown]
# ### Resolução do exercício 8

# %% [markdown]
#     @Test
#     void testSin(){
#         double sin = calc.sin(20);
#
#         assertEquals(0.3420201433256687, sin);
#     }
#
#     @Test
#     void testCos(){
#         double cos = calc.cos(20);
#
#         assertEquals(0.9396926207859084, cos);
#     }
#
#     @Test
#     void testLog(){
#         double log = calc.log(20);
#         Exception res = assertThrows(IllegalArgumentException.class, () -> calc.log(-20));
#
#         assertEquals(2.995732273553991, log);
#         assertEquals("Log of non-positive number", res.getMessage());
#     }

# %% [markdown]
# ![image.png](attachment:dc56500a-269c-4561-8d44-262027b4fb72.png)

# %% [markdown]
# ### Exercício 9 - Priorizando testes com base na cobertura e comportamento

# %% [markdown]
# Faça uma análise textual explicando:
#
# * Quais métodos da calculadora merecem mais atenção nos testes?
# * Como a cobertura de código pode ajudar a identificar lacunas?

# %% [markdown]
# ### Resolução do exercício 9

# %% [markdown]
# * Métodos que possuem condições ou verificações devem apresentar maior cuidado. Como divisão por 0 e raiz negativa, são testes que precisam ser pensados para garantir a ampla possibilidade de resultados.
# * A cobertura de código é útil porque permite analisar quais caminhos lógicos de um programa estão sendo testados. Estruturas como if, else, switch, try/catch e laços (for, while) podem produzir resultados diferentes dependendo da entrada.

# %% [markdown]
# ### Exercício 10 - Nomeando testes de forma adequada

# %% [markdown]
# * Revise os nomes de todos os testes criados. Renomeie aqueles que não seguem boas práticas de clareza e expressividade. Explique sua escolha em dois exemplos.

# %% [markdown]
# ### Resolução do exercício 10

# %% [markdown]
# Aqui eu renomearia o teste "testDivideByZero()" para "testDivisionByZero()" expressando corretamente a gramática, e os testes "testSin()", "testLog()" e "testCod()" para "testGeometricalSin()", "testGeometricalCos()" e "testGeometricalLog()" indicando operações geométricas.

# %% [markdown]
#     @Test
#     void testDivisionByZero(){
#
#         Exception res = assertThrows(IllegalArgumentException.class, () -> calc.divide(10, 0));
#
#         assertEquals("Division by zero", res.getMessage());
#     }
#
#     @Test
#     void testGeometricalSin(){
#         double sin = calc.sin(20);
#
#         assertEquals(0.3420201433256687, sin);
#     }
#
#     @Test
#     void testGeometricalCos(){
#         double cos = calc.cos(20);
#
#         assertEquals(0.9396926207859084, cos);
#     }
#
#     @Test
#     void testGeometricalLog(){
#         double log = calc.log(20);
#         Exception res = assertThrows(IllegalArgumentException.class, () -> calc.log(-20));
#
#         assertEquals(2.995732273553991, log);
#         assertEquals("Log of non-positive number", res.getMessage());
#     }

# %% [markdown]
# ### Exercício 11 - Organizando os testes por comportamento

# %% [markdown]
# * Organize seus testes em uma classe chamada ScientificCalculatorTest. Agrupe testes semelhantes (ex: testes de erro, testes de funções trigonométricas) usando comentários ou métodos auxiliares.

# %% [markdown]
# ### Resolução do exercício 11

# %% [markdown]
# Fiz a organização com @Nested para agrupar testes similares.

# %% [markdown]
#     @Nested
#     class basicMathsOperation{
#
#         // testAddition() aciona a fase de execution e assertion. Sendo execution a linha recebendo calc.subtract
#         // e assertion a linha assertEquals();
#         @Test
#         void testAddition(){
#             double addition = calc.add(1,2);
#
#             assertEquals(3, addition);
#         }
#
#         // testSubract() aciona a fase de execution e assertion. Sendo execution a linha recebendo calc.subtract
#         // e assertion a linha assertEquals();
#         @Test
#         void testSubtract() {
#             double sub = calc.subtract(1, 3);
#
#             assertEquals(-2, sub);
#         }
#
#         @Test
#         void testSquaredRoot(){
#
#             double sqr = calc.squareRoot(25);
#
#
#             assertEquals(5, sqr);
#
#         }
#     }
#
#     @Nested
#     class basicMathsOperationWithError {
#
#         @Test
#         void testSquareRootNegative() {
#
#             Exception res = assertThrows(IllegalArgumentException.class, () -> calc.squareRoot(-25));
#
#             assertEquals("Negative number", res.getMessage());
#         }
#
#         @Test
#         void testDivisionByZero() {
#
#             Exception res = assertThrows(IllegalArgumentException.class, () -> calc.divide(10, 0));
#
#             assertEquals("Division by zero", res.getMessage());
#         }
#     }
#
#     @Nested
#     class geometricalTests{
#         @Test
#         void testGeometricalSin(){
#             double sin = calc.sin(20);
#
#             assertEquals(0.3420201433256687, sin);
#         }
#
#         @Test
#         void testGeometricalCos(){
#             double cos = calc.cos(20);
#
#             assertEquals(0.9396926207859084, cos);
#         }
#
#         @Test
#         void testGeometricalLog(){
#             double log = calc.log(20);
#             Exception res = assertThrows(IllegalArgumentException.class, () -> calc.log(-20));
#
#             assertEquals(2.995732273553991, log);
#             assertEquals("Log of non-positive number", res.getMessage());
#         }
#     }

# %% [markdown]
# ### Resultado final do arquivo ScientificCalculatorTest.java

# %% [markdown]
#     package org.example;
#
#     import org.junit.jupiter.api.AfterEach;
#     import org.junit.jupiter.api.BeforeEach;
#     import org.junit.jupiter.api.Nested;
#     import org.junit.jupiter.api.Test;
#
#     import static org.junit.jupiter.api.Assertions.*;
#
#     public class ScientifcCalculatorTest {
#         private ScientificCalculator calc;
#
#         /*
#          @Test
#         public void testAddition(){
#             ScientificCalculator calculator = new ScientificCalculator();
#
#             double addition = calculator.add(1, 2);
#
#             assertEquals(3, addition);
#
#         }
#          */
#
#         /*
#          @Test
#         void testSubtract() {
#
#             //Setup
#             ScientificCalculator calculator = new ScientificCalculator();
#
#             //Execution
#             double sub = calculator.subtract(1, 3);
#
#             //Assertion
#             assertEquals(-2, sub);
#
#             //Teardown
#             System.out.println("Final do teste");
#         }
#          */
#
#         // Aqui ocorre o set up, indica que o teste se inicia com essa instância
#         // de calc e pode ser usado em todos os testes seguintes.
#         // O setUp() é iniciado toda vez que uma unidade de teste é acionada graças ao @BeforeEach..
#         @BeforeEach
#         void setUp() {
#             calc = new ScientificCalculator();
#             System.out.println("Iniciando teste.");
#         }
#
#         // Tear down é algum possível fechamento que precisa ser realizado, indica por exemplo,
#         // o fechamento do leitor de documentos por exemplo. Aqui para fins de visualização, o coloquei com uma
#         // mensagem de encerramento.
#         @AfterEach
#         void tearDown() {
#             System.out.println("Finalizando teste");
#         }
#
#
#
#         @Nested
#         class basicMathsOperation{
#
#             // testAddition() aciona a fase de execution e assertion. Sendo execution a linha recebendo calc.subtract
#             // e assertion a linha assertEquals();
#             @Test
#             void testAddition(){
#                 double addition = calc.add(1,2);
#
#                 assertEquals(3, addition);
#             }
#
#             // testSubract() aciona a fase de execution e assertion. Sendo execution a linha recebendo calc.subtract
#             // e assertion a linha assertEquals();
#             @Test
#             void testSubtract() {
#                 double sub = calc.subtract(1, 3);
#
#                 assertEquals(-2, sub);
#             }
#
#             @Test
#             void testSquaredRoot(){
#
#                 double sqr = calc.squareRoot(25);
#
#
#                 assertEquals(5, sqr);
#
#             }
#         }
#
#         @Nested
#         class basicMathsOperationWithError {
#
#             @Test
#             void testSquareRootNegative() {
#
#                 Exception res = assertThrows(IllegalArgumentException.class, () -> calc.squareRoot(-25));
#
#                 assertEquals("Negative number", res.getMessage());
#             }
#
#             @Test
#             void testDivisionByZero() {
#
#                 Exception res = assertThrows(IllegalArgumentException.class, () -> calc.divide(10, 0));
#
#                 assertEquals("Division by zero", res.getMessage());
#             }
#         }
#
#         @Nested
#         class geometricalTests{
#             @Test
#             void testGeometricalSin(){
#                 double sin = calc.sin(20);
#
#                 assertEquals(0.3420201433256687, sin);
#             }
#
#             @Test
#             void testGeometricalCos(){
#                 double cos = calc.cos(20);
#
#                 assertEquals(0.9396926207859084, cos);
#             }
#
#             @Test
#             void testGeometricalLog(){
#                 double log = calc.log(20);
#                 Exception res = assertThrows(IllegalArgumentException.class, () -> calc.log(-20));
#
#                 assertEquals(2.995732273553991, log);
#                 assertEquals("Log of non-positive number", res.getMessage());
#             }
#         }
#     }
